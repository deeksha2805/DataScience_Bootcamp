# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
#Load csv file using the file path
x = pd.read_csv("/Users/deeksha/Downloads/Standard_Metropolitan_Areas_train_data.csv")

# %%
x
# Out:
#     land_area  percent_city  percent_senior  physicians  hospital_beds  \
# 0        1384          78.1            12.3       25627          69678
# 1        3719          43.9             9.4       13326          43292
# 2        3553          37.4            10.7        9724          33731
# 3        3916          29.9             8.8        6402          24167
# 4        2480          31.5            10.5        8502          16751
# ..        ...           ...             ...         ...            ...
# 94       1511          38.7            10.7         348           1093
# 95       1543          39.6             8.1         159            481
# 96       1011          37.8            10.5         264            964
# 97        813          13.4            10.9         371           4355
# 98        654          28.8             3.9         140           1296
#
#     graduates  work_force  income  region  crime_rate
# 0        50.1      4083.9   72100       1       75.55
# ...

# %%
##Provides the essential details about your dataset, such as the number of rows and columns, 
#the number of non-null values, what type of data is in each column, and how much memory your DataFrame is using.

x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99 entries, 0 to 98
# Data columns (total 10 columns):
# land_area         99 non-null int64
# percent_city      99 non-null float64
# percent_senior    99 non-null float64
# physicians        99 non-null int64
# hospital_beds     99 non-null int64
# graduates         99 non-null float64
# work_force        99 non-null float64
# income            99 non-null int64
# region            99 non-null int64
# crime_rate        99 non-null float64
# dtypes: float64(5), int64(5)
# memory usage: 7.9 KB

# %%
#Has no parentheses and is a simple tuple of format (rows, columns). 
#So I have 99 rows and 10 columns in the Train DataFrame.

x.shape
# Out:
# (99, 10)

# %%
x.columns
# Out:
# Index(['land_area', 'percent_city', 'percent_senior', 'physicians',
#        'hospital_beds', 'graduates', 'work_force', 'income', 'region',
#        'crime_rate'],
#       dtype='object')

# %%
#We can get a summary of the distribution of continuous variables using .describe()
x.describe()
# Out:
#           land_area  percent_city  percent_senior    physicians  \
# count     99.000000     99.000000       99.000000     99.000000
# mean    2615.727273     42.518182        9.781818   1828.333333
# std     3045.826210     17.348277        2.524547   3192.199763
# min       47.000000     13.400000        3.900000    140.000000
# 25%     1408.000000     30.100000        8.350000    459.000000
# 50%     1951.000000     39.500000        9.700000    774.000000
# 75%     2890.500000     52.600000       10.750000   1911.500000
# max    27293.000000    100.000000       21.800000  25627.000000
#
#        hospital_beds  graduates   work_force        income     region  \
# count      99.000000  99.000000    99.000000     99.000000  99.000000
# mean     6345.868687  54.463636   449.366667   6762.505051   2.494949
# std      9136.202716   7.773286   610.990885  10393.349660   1.013921
# min       481.000000  30.300000    66.900000    769.000000   1.000000
# ...

# %%
#We can also find individual data (if needed)
x['land_area'].describe()
# Out:
# count       99.000000
# mean      2615.727273
# std       3045.826210
# min         47.000000
# 25%       1408.000000
# 50%       1951.000000
# 75%       2890.500000
# max      27293.000000
# Name: land_area, dtype: float64

# %%
# .value_counts() tells the frequency of all values in a column, .head() gives the required columns.
x['region'].value_counts().head(4)
# Out:
# 3    36
# 2    25
# 1    21
# 4    17
# Name: region, dtype: int64

# %%
# .corr() is used to generate the relationship between each continuous variable. CORRELATION
x.corr()
# Out:
#                 land_area  percent_city  percent_senior  physicians  \
# land_area        1.000000     -0.077320        0.092226    0.085054
# percent_city    -0.077320      1.000000       -0.250995    0.067391
# percent_senior   0.092226     -0.250995        1.000000    0.056454
# physicians       0.085054      0.067391        0.056454    1.000000
# hospital_beds    0.081034      0.052898        0.083775    0.974241
# graduates        0.088728      0.076720       -0.155695    0.049500
# work_force       0.135792      0.016011        0.035240    0.965597
# income           0.111404      0.019235        0.046073    0.976209
# region           0.292392      0.235880       -0.242811   -0.140961
# crime_rate       0.293907      0.159596       -0.177992    0.187763
#
#                 hospital_beds  graduates  work_force    income    region  \
# land_area            0.081034   0.088728    0.135792  0.111404  0.292392
# ...

# %%
#The first five land area of the metropolitan area data which are located in region 4
x[x['region'] == 4]['land_area'].head()
# Out:
# 4      2480
# 13      782
# 14     4226
# 18    27293
# 20     9155
# Name: land_area, dtype: int64

# %%
x[(x['region'] == 1) & (x['crime_rate'] >= 54.16)]
# Out:
#     land_area  percent_city  percent_senior  physicians  hospital_beds  \
# 0        1384          78.1            12.3       25627          69678
# 10       1008          16.6            10.3        4006          16704
# 24       2966          26.9            10.3        2053           6604
# 55        192          60.5            10.8         617           1789
#
#     graduates  work_force  income  region  crime_rate
# 0        50.1      4083.9   72100       1       75.55
# 10       55.9       935.5   15953       1       54.16
# 24       56.3       450.4    6966       1       56.55
# 55       44.1       212.6    3158       1       58.79

# %%
x[(x['region'] == 3) | (x['land_area'] >= 5000)].shape
# Out:
# (41, 10)

# %%
x[(x['region'] == 4) & (x['crime_rate'] == 85.62)]
# Out:
#     land_area  percent_city  percent_senior  physicians  hospital_beds  \
# 20       9155          53.8            11.1        2280           6450
#
#     graduates  work_force  income  region  crime_rate
# 20       60.1       575.2    7766       4       85.62

# %%
x.plot(kind = 'line', x = 'land_area', y = 'crime_rate'); 
#semicolon is used to hide matplotlib.axes._subplots.AxesSubplot at 0x26613b5cc18> o

# %%
x.plot(kind = 'scatter', x = "hospital_beds" , y = 'physicians');

# %%
x['income'].plot(kind = 'hist', title = 'Total income in 1976 in millions of dollars');
